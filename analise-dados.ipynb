# %%
import pandas as pd

# %% [markdown]
# ## IMPORTANDO DADOS

# %%
df = pd.read_table("data/2004-2021.tsv")

# %%
df.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %% [markdown]
# ## ANÁLISE EXPLORATÓRIA

# %% [markdown]
# *CRIANDO NOVAS FEATURES*

# %%
df["DATA INICIAL"] = pd.to_datetime(df["DATA INICIAL"])
df["DATA FINAL"] = pd.to_datetime(df["DATA FINAL"])
df["MES"] = df["DATA INICIAL"].dt.month
df["ANO"] = df["DATA INICIAL"].dt.year
df['MES/ANO'] = df['DATA INICIAL'].dt.strftime('%m/%Y')

# %% [markdown]
# *RENOMEANDO FEATURES*

# %%
df.rename(columns={"DATA INICIAL":"DATA", "PREÇO MÉDIO REVENDA": "VALOR REVENDA"},inplace = True)

# %%
df["PRODUTO"].value_counts()
# Out:
# GASOLINA COMUM        23570
# GLP                   23561
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# GNV                   14469
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: PRODUTO, dtype: int64

# %%
df.head()
# Out:
#         DATA DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0 2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1 2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2 2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3 2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4 2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  VALOR REVENDA  \
# 0                           127              R$/l          1.288
# 1                           387              R$/l          1.162
# 2                           192              R$/l          1.389
# 3                           162              R$/l          1.262
# 4                           103              R$/l          1.181
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                  0.016                  1.19  ...                 0.463
# 1                  0.114                  0.89  ...                 0.399
# 2                  0.097                  1.18  ...                 0.419
# 3                  0.070                  1.09  ...                 0.432
# 4                  0.078                  1.05  ...                  0.24
#
#   COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                    0.012                     0.825
# 1                    0.098                     0.763
# 2                    0.070                      0.97
# 3                    0.055                      0.83
# 4                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MES   ANO  MES/ANO
# 0                    0.9666                         0.133   5  2004  05/2004
# 1                      1.05                         0.115   5  2004  05/2004
# 2                     1.161                         0.098   5  2004  05/2004
# 3                   1.22242                         0.143   5  2004  05/2004
# 4                    1.0317                         0.082   5  2004  05/2004
#
# [5 rows x 21 columns]

# %% [markdown]
# **REALIZANDO FILTRO NO DF**

# %% [markdown]
# *SELECIONANDO PRODUTO = GASOLUNA COMUM*

# %%
df_gasolina = df[df["PRODUTO"] == "GASOLINA COMUM"].reset_index(drop = ["index"])

df_gasolina = df_gasolina[["DATA", "REGIÃO", "ESTADO", "VALOR REVENDA", "ANO", "MES", "MES/ANO"]]

# %%
df_gasolina["ANO"] = df_gasolina["ANO"].astype(str)

# %% [markdown]
# ## SALVANDO ARQUIVO CSV

# %%
df_gasolina.to_csv("data/2004-2021-gasolina.csv")
